# %%
from utils import get_lowered_from_txt, get_data_from_book
get_data_from_book("https://www.gutenberg.org/cache/epub/4078/pg4078.txt","pdg")
lowered = get_lowered_from_txt("pdg")

# %%
from utils import plot_most_freq_words
plot_most_freq_words(lowered, 30)

# %%
lowered
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'picture',
#  'of',
#  'dorian',
#  'gray',
#  'by',
#  'oscar',
#  'wilde',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'you',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www',
#  'gutenberg',
#  'org',
#  'title',
#  'the',
#  'picture',
#  'of',
#  'dorian',
#  'gray',
#  '13',
#  'chapter',
#  'version',
#  'author',
#  'oscar',
#  'wilde',
#  'posting',
#  'date',
#  'february',
#  '9',
#  '2013',
#  'ebook',
#  '4078',
#  'release',
#  'date',
#  'may',
#  '2003',
#  'first',
#  'posted',
#  'november',
#  '12',
# ...

# %%
from utils import plot_num_word_lengths_in_single_book
plot_num_word_lengths_in_single_book(lowered)

# %%
from utils import plot_num_word_lengths_in_single_book, plot_most_freq_words
plot_num_word_lengths_in_single_book(lowered)
# cut out the 30 most common words in the english language - after 
plot_most_freq_words(lowered, 20)

# %%
from utils import get_data_from_book
lowered_4 = get_data_from_book(
    "https://www.gutenberg.org/cache/epub/174/pg174-images.html",
    "pdg"
)

# %%
from utils import get_sentences_from_txt
sentences = get_sentences_from_txt("pdg")
sentences
# Out:
# ['the project gutenberg ebook of the picture of dorian gray, by oscar wilde this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever.',
#  'you may copy it, give it away or re-use it under the terms of the project gutenberg license included with this ebook or online at www.gutenberg.org title: the picture of dorian gray 13 chapter version author: oscar wilde posting date: february 9, 2013 [ebook #4078] release date: may, 2003 first posted: november 12, 2001 last updated: january 29, 2005 language: english *** start of this project gutenberg ebook the picture of dorian gray *** produced by alfred j. drake.',
#  'html version by al haines.',
# ...

# %%
from utils import split_into_lowered_sentences
sentences = split_into_lowered_sentences("pdg.txt")
sentences
# Out:
# ['pdg.']

# %%
from utils import get_alliteration_score, get_sentences_from_txt, get_alliteration_by_phoneme
import matplotlib.pyplot as plt
sentences = get_sentences_from_txt("pdg")
get_alliteration_score(sentences)
phoneme_dict = get_alliteration_by_phoneme(sentences, "Picture of Dorian Gray")
phonemes = list(phoneme_dict.keys())
num_occurences = list(phoneme_dict.values())
plt.bar(range(len(phoneme_dict)), num_occurences, tick_label= phonemes)
# Out:
# ['EH1', 'NONE', None, None]
# ['NONE', 'EH1', None, None]
# ['NONE', 'AA1', None, None]
# ['B', 'NONE', None, None]
# ['NONE', 'EY1', None, None]
# ['NONE', 'K', None, None]
# ['NONE', 'EH1', None, None]
# ['NONE', 'EH1', None, None]
# ['NONE', 'EH1', None, None]
# ['IY1', 'AA1', None, None]
# ['IY1', 'NONE', None, None]
# ['NONE', 'EH1', None, None]
# ['NONE', 'S', None, None]
# ['NONE', 'EH1', None, None]
# ['EH1', 'NONE', None, None]
# ['EH1', 'NONE', None, None]
# ['EH1', 'NONE', None, None]
# ['AA1', 'IY1', None, None]
# ['IY1', 'V', None, None]
# ['NONE', 'Y', None, None]
# ['NONE', 'P', None, None]
# ['NONE', 'NONE', None, None]
# ['NONE', 'IY1', None, None]
# ['D', 'NONE', None, None]
# ['AA1', 'NONE', None, None]
# ['AA1', 'NONE', None, None]
# ['IY1', 'NONE', None, None]
# ['NONE', 'IY1', None, None]
# ['EH1', 'NONE', None, None]
# ['IY1', 'EH1', None, None]
# ['EH1', 'S', None, None]
# ['NONE', 'EY1', None, None]
# ['NONE', 'EY1', None, None]
# ['NONE', 'AA1', None, None]
# ...

# %%
def get_alliteration_level(sentences):  # alliteration based on sound, not only letter!
    count, total_words = 0, 0
    proximity = 4  # max phonemes to compare to for consideration of alliteration
    i = 0  # index for placing phonemes into current_phonemes
    for sentence in sentences:
        current_phonemes = [None] * proximity
        for word in sentence:
            word = no_punct(word)  # remove punctuation marks for correct identification
            total_words += 1
            if word not in stopwords:
                if get_phonemes(word)[0] in current_phonemes:  # alliteration occurred
                    count += 1
                current_phonemes[i] = get_phonemes(word)[
                    0
                ]  # update new comparison phoneme
                i = 0 if i == 1 else 1  # update storage index

    alliteration_score = count / total_words
    return count

# %%
from utils import get_part_of_speech_usage_one_book
get_part_of_speech_usage_one_book("pdg")
# Out:
# Word            POS Tag
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from utils import get_part_of_speech_usage_one_book
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> get_part_of_speech_usage_one_book("pdg")
#
# File ~/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/utils.py:241, in get_part_of_speech_usage_one_book(text_file)
#     239 text = Text(f_text)
# ...

# %%
from utils import get_avg_sentence_length_all_books
get_avg_sentence_length_all_books()

# %%
from utils import get_polarity_character
get_polarity_character("pdg", "Dorian")
# Out:
# the project  ebook of the picture of dorian gray, by   this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever  you may copy it, give it away or re-use it under the terms of the project  license included with this ebook or online at www  org title: the picture of dorian gray 13 chapter version author:   posting date: february 9, 2013 [ebook #4078] release date: may, 2003 first posted: november 12, 2001 last updated: january 29, 2005 language: english *** start of this project  ebook the picture of dorian gray *** produced by  j    the picture of dorian gray by   1890, 13-chapter version contents chapter i: 3-12 chapter ii: 12-22 chapter iii: 22-32 chapter iv: 32-36 chapter v: 36-43 chapter vi: 43-52 chapter vii: 52-58 chapter viii: 58-64 chapter ix: 65-77 chapter x: 77-81 chapter xi: 81-86 chapter xii: 86-93 chapter xiii: 94-100 chapter i [3] the studio was filled with the rich odor of roses, and when the light summer wind stirred amidst the
# ...

# %%
from utils import get_all_alliteration_by_phoneme
get_all_alliteration_by_phoneme()
# Out:
# {'for': 6, 'miss': 2, 'grave': 1, 'left': 2, 'love': 1, 'class': 1, 'pray': 1, 'little': 2, 'dreadful': 2, 'my': 6, 'opera': 1, 'told': 1, 'like': 1, 'most': 3, 'more': 2, 'inquire': 1, 'bit': 2, 'modern': 2, 'deal': 1, 'big': 1, 'are': 1, 'drive': 1, 'speech': 1, 'buy': 1, 'ennobling': 1, 'meet': 2, 'am': 1, 'always': 1, 'half': 1, 'brooch': 1, 'wheels': 1, 'no': 3, 'scandalous': 1, 'day': 1, 'life': 1, 'should': 4, 'without': 2, 'baron': 1, 'strange': 1, 'fortunately': 1, 'terrible': 1, 'were': 1, 'finance': 1, 'silly': 1, 'money': 1, 'whatever': 1, 'smallest': 1, 'secret': 1, 'sure': 1, 'worth': 3, 'looks': 2, 'high': 1, 'she': 3, 'robert': 1, 'badly': 1, 'tommy': 2, 'art': 1, 'anybody': 1, 'say': 1, 'horrid': 1, 'commons': 1, 'happy': 1, 'since': 1, 'before': 1, 'blue': 1, 'painfully': 1, 'hides': 1, 'langton': 1, 'same': 1, 'bow': 1, 'from': 1, 'alter': 1, 'comparatively': 1, 'god': 2, 'mind': 1, 'perfect': 1, 'two': 1, 'put': 1, 'fallen': 2, 'upright': 1, 'anything': 1, 'articl
# ...

# %%
from utils import get_data_from_all_books
get_data_from_all_books()

# %%
from utils import plot_most_freq_words_texts
plot_most_freq_words_texts()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from utils import plot_most_freq_words_texts
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/jes-bro/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/test.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plot_most_freq_words_texts()
#
# File ~/softdes-2023-01/midterm_project/oscar_wilde_literary_devices/utils.py:151, in plot_most_freq_words_texts()
#     149     sentences = get_sentences_from_txt(book[1])
#     150     lowered_sentences = split_sentences_into_lists_of_words(sentences)
# ...
